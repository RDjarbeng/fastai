# %% [markdown]
# # Lesson 7
#
#
# Ensembling and models with multiple outputs. For multiple outputs need some changes to the dataloaders.
#
# Easy to do in fast ai- image data block from folders is replaced with DataBlock
#
# Set the blocks to be as many as you like, in this case 1 image, 2 categories
# Have to specify the number of inputs using n_inp
#
# get_y, the labeling function, can receive 2 items as a list

# %% [markdown]
# In pandas setting a column as the index makes it behave similar to a dictionary,so you can index the df.
#
# Because of the multiple categories, we set loss function to cross entropy loss.
# Outputs for the Category are given as numbers, converted to exponentials, softmax fits these predictions as probabilities (0-1) across the various categories.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Calculating cross entropy with the actual values and the softmax values.
# Most values will be 0 since the actual value is 0. The one value that's one hot encoded as 1
# will be multiplied by the log of the softmax.
#
# Simply take the log of the
#
# ![image.png](attachment:image.png)

# %%
Remember a log graph of numbers less than 1 looks like this:
